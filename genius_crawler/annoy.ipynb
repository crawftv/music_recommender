# %%
#!conda uninstall pandas -y

# %%
#!conda install pandas -y

# %%
import pandas
import annoy

# %%
df = pd.read_csv("1_9_million_songs.csv")

# %%
# !pip install annoy
# Out:
# ...
#     100% |████████████████████████████████| 645kB 31.0MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for annoy ... done
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/d4/78/3a/1c913a402f4d84f68eb0ea4f7c0de0d392725415c8ebe51068
# Successfully built annoy
# ...
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from annoy import AnnoyIndex
b = AnnoyIndex(200)
b.load('test.ann')
# Out:
# True

# %%
df.song_num.loc[1]
# Out:
# 358490

# %%
z = b.get_nns_by_item(358490, 10)

# %%
# Out:
#          song_num                                      title  \
# 358490    1708810               I Left My Flannel in Seattle
# 347661    1697521                                    God Man
# 955095    1035161  In Mortal Darkness (Life & Death Part Ii)
# 1682416   1679762                      You Wish You Were Red
# 645139     853087                                  Ignoramus
# 1790045    132665                                Letter Home
# 878283    2141102              The Warmth Of Wooden Lanterns
# 425464     175426    The Maid of Orleans (Dramatis Personae)
# 1825271   1287260                                  The Curse
# 1538505   1537411                           Almost Persuaded
#
#                                                        url  \
# 358490   https://genius.com/Butt-trumpet-i-left-my-flan...
# 347661        https://genius.com/Sear-bliss-god-man-lyrics
# 955095   https://genius.com/Penitent-in-mortal-darkness...
# ...
