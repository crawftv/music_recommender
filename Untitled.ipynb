# %%
import pandas as pd

# %%
df = pd.read_csv("songs_lists.csv")

# %%
df
# Out:
#                                            release_wiki  \
# 0                         /wiki/Based_on_a_T.R.U._Story
# 1                          /wiki/B.O.A.T.S._II:_Me_Time
# 2                                      /wiki/ColleGrove
# 3                    /wiki/Pretty_Girls_Like_Trap_Music
# 4                         /wiki/Rap_or_Go_to_the_League
# 5                                /wiki/T.R.U._REALigion
# 6                        /wiki/Daniel_Son;_Necklace_Don
# 7                               /wiki/Hibachi_for_Lunch
# 8              /wiki/The_Play_Don%27t_Care_Who_Makes_It
# 9                   /wiki/Death_Before_Dishonor_(album)
# 10                                     /wiki/Issa_Album
# 11                        /wiki/I_Am_Greater_than_I_Was
# 12    /wiki/Without_Warning_(21_Savage,_Offset_and_M...
# 13                             /wiki/The_Slaughter_Tape
# 14                                 /wiki/Slaughter_King
# 15                                    /wiki/Savage_Mode
# ...
