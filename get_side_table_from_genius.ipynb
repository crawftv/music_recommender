# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://genius.com/Earl-sweatshirt-am-radio-lyrics')
soup = BeautifulSoup(page.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="snarly apple_music_player--enabled bagon_song_page--enabled song_stories_public_launch--enabled react_forums--disabled react_home_page--disabled" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">
# <head>
# <base href="//genius.com/" target="_top"/>
# <script type="text/javascript">
# //<![CDATA[
#
#   var _sf_startpt=(new Date()).getTime();
#   if (window.performance && performance.mark) {
#     window.performance.mark('parse_start');
#   }
#
# //]]>
# </script>
# <title>Earl Sweatshirt – AM // Radio Lyrics | Genius Lyrics</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="app-id=709482991" name="apple-itunes-app"/>
# <link href="https://assets.genius.com/images/apple-touch-icon.png?1554323218" rel="apple-touch-icon"/>
# ...

# %%
side_list_table = soup.find_all("div", {"class":"metadata_unit metadata_unit--table_row"} )

# %%
side_list_table[0]
#= side_list_table.find_all("a")
# Out:
# <div class="metadata_unit metadata_unit--table_row">
# <span class="metadata_unit-label">Written By</span>
# <span class="metadata_unit-info">
# <a href="https://genius.com/artists/Earl-sweatshirt">Earl Sweatshirt</a> &amp; <a href="https://genius.com/artists/Wiki">Wiki</a>
# </span>
# </div>

# %%
a =side_list_table[0].find_all("span", {"class":"metadata_unit-label"})
a[0].text
# Out:
# 'Written By'

# %%
a =side_list_table[0].find_all("a")
def get_links(x,i):
    return x[i]['href']

# %%
get_links(a,0)
# Out:
# 'https://genius.com/artists/Earl-sweatshirt'

# %%
s = side_list_table[0]

a = s.find_all("span", {"class":"metadata_unit-label"})
a[0].text
#[ get_links(s,i) for i in range(len(s))]
# Out:
# 'Written By'

# %%
l = s.find_all("a")

# %%
[get_links(l,i) for i in range(len(l))]
# Out:
# ['https://genius.com/artists/Earl-sweatshirt',
#  'https://genius.com/artists/Wiki']

# %%
def get_table_row(side_list_table_row):
    a = side_list_table_row.find_all("span", {"class":"metadata_unit-label"})
    label = a[0].text
    links_list = side_list_table_row.find_all("a")
    links = [get_links(links_list,i) for i in range(len(links_list))]
    return label,links

# %%
s = side_list_table[0]
get_table_row(s)
# Out:
# ('Written By',
#  ['https://genius.com/artists/Earl-sweatshirt',
#   'https://genius.com/artists/Wiki'])

# %%
side_list_table = soup.find_all("div", {"class":"metadata_unit metadata_unit--table_row"} )
table = [get_table_row(side_list_table[i]) for i in range(0,len(side_list_table)) ]

# %%
def get_table_row(side_list_table_row):
    a = side_list_table_row.find_all("span", {"class":"metadata_unit-label"})
    label = a[0].text
    links_list = side_list_table_row.find_all("a")
    links = [get_links(links_list,i) for i in range(len(links_list))]
    return label,links
def get_table_from_page(url):
    page = requests.get('https://genius.com/Earl-sweatshirt-am-radio-lyrics')
    soup = BeautifulSoup(page.text,'html.parser')
    side_list_table = soup.find_all("div", {"class":"metadata_unit metadata_unit--table_row"} )
    return [get_table_row(side_list_table[i]) for i in range(0,len(side_list_table)) ]

# %%
get_table_from_page('https://genius.com/Earl-sweatshirt-am-radio-lyrics')
# Out:
# [('Written By',
#   ['https://genius.com/artists/Earl-sweatshirt',
#    'https://genius.com/artists/Wiki']),
#  ('Engineer',
#   ['https://genius.com/artists/Echo-producer',
#    'https://genius.com/artists/Vic-wainstein',
#    'https://genius.com/artists/Larry-fisherman']),
#  ('Co-Production', ['https://genius.com/artists/Miles-shannon']),
#  ('Recording Engineer', ['https://genius.com/artists/John-foyle']),
#  ('Label',
#   ['https://genius.com/artists/Tan-cressida',
#    'https://genius.com/artists/Columbia-records']),
#  ('Release Date', []),
#  ('Samples', ['https://genius.com/G-herbo-knucklehead-lyrics'])]
