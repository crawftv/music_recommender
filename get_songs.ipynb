# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import numpy as np

# %%
albums = pd.read_csv("artist_and_albums.csv")

# %%
albums.head()
# Out:
#                          release_wiki                  release_name  \
# 0       /wiki/Based_on_a_T.R.U._Story       Based on a T.R.U. Story
# 1        /wiki/B.O.A.T.S._II:_Me_Time        B.O.A.T.S. II: Me Time
# 2                    /wiki/ColleGrove                    ColleGrove
# 3  /wiki/Pretty_Girls_Like_Trap_Music  Pretty Girls Like Trap Music
# 4       /wiki/Rap_or_Go_to_the_League       Rap or Go to the League
#
#    wikipedia_page      name
# 0  /wiki/2_Chainz  2 Chainz
# 1  /wiki/2_Chainz  2 Chainz
# 2  /wiki/2_Chainz  2 Chainz
# 3  /wiki/2_Chainz  2 Chainz
# 4  /wiki/2_Chainz  2 Chainz

# %%
base = 'https://en.wikipedia.org'

# %%
page = requests.get(base+'/wiki/ColleGrove')
soup = BeautifulSoup(page.text,'html.parser')

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>ColleGrove - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"ColleGrove","wgTitle":"ColleGrove","wgCurRevisionId":889644044,"wgRevisionId":889644044,"wgArticleId":49509344,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Articles with hAudio microformats","2016 albums","2 Chainz albums","Albums produced by Mannie Fresh","Albums produced by Lil\' C (record producer)","Def Jam Recordings albums","Albums produced by Mike Will Made It","Albums produced by Metro Boomin","Albums produced by Zaytoven","Albums pro
# ...

# %%
tracklist_table = soup.find_all("table", {"class":"tracklist"} )

# %%
tracklist_table
# Out:
# [<table class="tracklist" style="display:block;border-spacing:0px;border-collapse:collapse;padding:4px"><tbody><tr><th class="tlheader mbox-text" colspan="5" style="text-align:left;background-color:#fff">Standard edition</th></tr><tr><th class="tlheader" scope="col" style="width:2em;padding-left:10px;padding-right:10px;text-align:right;background-color:#eee"><abbr title="Number">No.</abbr></th><th class="tlheader" scope="col" style="width:40%;text-align:left;background-color:#eee">Title</th><th class="tlheader" scope="col" style="width:30%;text-align:left;background-color:#eee">Writer(s)</th><th class="tlheader" scope="col" style="width:30%;text-align:left;background-color:#eee">Producer(s)</th><th class="tlheader" scope="col" style="width:4em;padding-right:10px;text-align:right;background-color:#eee">Length</th></tr><tr style="background-color:#fff"><td style="padding-right:10px;text-align:right;vertical-align:top">1.</td><td style="vertical-align:top">"Dedication"</td><td style="ve
# ...

# %%
artists_lists = tracklist_table[0].find_all("td")
type(artists_lists[0])
# Out:
# bs4.element.Tag

# %%
i = list(map(lambda x : re.sub(r'<.*?>',' ',str(x) ),artists_lists))

# %%
i[0:5]
# Out:
# [' 1. ',
#  ' "Dedication" ',
#  '     Tauheed Epps    Joshua Luellen    Michael Dean     ',
#  '     Southside   Dean  [a]      ',
#  ' 4:59 ']

# %%
i[5:10]
# Out:
# [' 2. ',
#  ' "Smell Like Money"  (featuring  Lil Wayne )  ',
#  '    Epps   Dwayne Carter, Jr.    Carlton Mays, Jr.     ',
#  '  Honorable C.N.O.T.E.  ',
#  ' 4:50 ']
